# %%
import pandas as pd

# %%
df = pd.read_parquet('/workspaces/Bluebikes-trip-mlops/data/2023-07-bluebikes-tripdata.parquet')

# %%
df
# Out:
#                  ride_id rideable_type           started_at  \
# 0       C694F27EDA2FB2A3   docked_bike  2023-07-18 13:48:34
# 1       E182C085A7901BD0   docked_bike  2023-07-19 12:16:30
# 2       EEAB121638F88C65   docked_bike  2023-07-28 17:49:26
# 3       1A1EAD7F0B0D3EC9   docked_bike  2023-07-22 23:14:17
# 4       53822DB5B536A35B   docked_bike  2023-07-21 18:41:22
# ...                  ...           ...                  ...
# 411504  A4742E9801481384   docked_bike  2023-07-05 12:36:57
# 411505  364B1DBD9A0F1FCD   docked_bike  2023-07-10 10:58:53
# 411506  EE549C7467BC5FEF   docked_bike  2023-07-07 10:13:01
# 411507  55D33AD303859E02   docked_bike  2023-07-15 04:16:48
# 411508  192CFF3DBF7E3388   docked_bike  2023-07-14 21:13:23
#
#                    ended_at  \
# 0       2023-07-18 13:58:44
# 1       2023-07-19 12:25:23
# 2       2023-07-28 18:00:08
# 3       2023-07-22 23:23:32
# 4       2023-07-21 18:49:00
# ...                     ...
# 411504  2023-07-05 12:48:24
# ...

# %%
df_2 = pd.read_parquet('/workspaces/Bluebikes-trip-mlops/data/predicted_202307.parquet')

# %%
df_2
# Out:
#                  ride_id  predicted_duration
# 0       C694F27EDA2FB2A3           13.945983
# 1       E182C085A7901BD0           13.945983
# 2       EEAB121638F88C65           13.945983
# 3       1A1EAD7F0B0D3EC9           13.945983
# 4       53822DB5B536A35B           13.713597
# ...                  ...                 ...
# 392145  96AD300A6A44CE6E           13.407084
# 392146  A4742E9801481384           11.368688
# 392147  364B1DBD9A0F1FCD           11.368688
# 392148  EE549C7467BC5FEF           11.368688
# 392149  192CFF3DBF7E3388           11.368688
#
# [392150 rows x 2 columns]
